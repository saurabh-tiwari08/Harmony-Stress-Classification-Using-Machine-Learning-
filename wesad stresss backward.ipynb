# %% [markdown]
# importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_classif,chi2,mutual_info_classif
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score,precision_score,recall_score,accuracy_score
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

# %% [markdown]
# reading data from csv

# %%
data=pd.read_csv(r'C:\Users\anura\Downloads\stresssss\WESAD (Raw and Processed)\dataset\2. final\datasets\hrv\wesad\combined\classification\wesad-chest-combined-classification-hrv.csv')
test=pd.read_csv(r'C:\Users\anura\Downloads\stresssss\WESAD (Raw and Processed)\dataset\2. final\datasets\hrv\wesad\combined\classification\wesad-classification-hrv-validation-dataset.csv')

# %%
test.head(5)
# Out:
#       MEAN_RR   MEDIAN_RR       SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  836.287509  836.542330  74.347097  18.992200  18.990146    3.914612
# 1  885.066916  888.885335  54.149345  10.603410  10.602391    5.106786
# 2  617.957952  611.532195  62.909515  11.314677  11.314522    5.559992
# 3  590.628007  578.585925  51.127837  13.373595  13.370766    3.823043
# 4  705.684374  702.068590  46.416132   9.503709   9.494806    4.884002
#
#            HR  pNN25  pNN50        SD1  ...  MEAN_RR_MEAN_MEAN_REL_RR  \
# 0   72.328641  20.25   0.25  13.444920  ...              3.929834e+06
# 1   68.058181   2.00   0.00   7.506435  ...              5.925739e+06
# 2   98.041651   3.25   0.25   8.010620  ...              6.120832e+06
# 3  102.292102   7.25   0.75   9.466430  ...              1.819001e+06
# 4   85.390357   2.75   0.00   6.722271  ...              1.128313e+06
#
#      SD2_LF     HR_LF      HR_HF    HF_VLF  subject id  condition  SSSQ class  \
# 0  0.057583  0.039940   4.192356  0.010687          11   baseline         low
# 1  0.150989  0.134839  12.918568  0.007719           6   baseline      medium
# 2  0.079972  0.088488   3.443774  0.017516          13     stress      medium
# 3  0.056556  0.080706   1.164296  0.243491          17     stress      medium
# 4  0.132048  0.172682   2.749117  0.066276          13   baseline      medium
#
#    SSSQ Label  condition label
# 0           0                0
# 1           1                0
# 2           1                2
# 3           1                2
# 4           1                0
#
# [5 rows x 67 columns]

# %%
data.head(5)
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  660.756625  657.242305   34.857082   7.408307   7.408129    4.705134
# 1  762.004543  769.028815  106.035926  13.591780  13.580221    7.801475
# 2  978.587122  973.028365   80.323113  20.318045  20.316451    3.953289
# 3  690.333891  669.548460   79.677822  15.173680  15.173087    5.251055
# 4  724.270331  721.597785   71.663062  13.580379  13.580370    5.276956
#
#           HR  pNN25  pNN50        SD1  ...  MEAN_RR_MEAN_MEAN_REL_RR  \
# 0  91.050077   1.75   0.00   5.244915  ...              1.092856e+07
# 1  80.267696   6.00   1.00   9.614723  ...             -1.039564e+06
# 2  61.720802  20.50   1.50  14.383937  ...             -3.073518e+06
# 3  87.996270   8.75   1.50  10.742463  ...             -4.341078e+06
# 4  83.637107   5.00   0.75   9.614828  ...              1.311140e+07
#
#      SD2_LF     HR_LF      HR_HF    HF_VLF  subject id  condition  SSSQ class  \
# 0  0.134410  0.249678   7.068440  0.033515          13   baseline      medium
# 1  0.125816  0.067484   5.971604  0.003921           9   baseline         low
# 2  0.069888  0.038281  10.945519  0.003154           4  amusement      medium
# 3  0.094345  0.074014   2.435759  0.009692           8     stress         low
# 4  0.076385  0.063323   3.259253  0.014438           4     stress      medium
#
#    SSSQ Label  condition label
# 0           1                0
# 1           0                0
# 2           1                1
# 3           0                2
# 4           1                2
#
# [5 rows x 67 columns]

# %%
test.describe()
# Out:
#             MEAN_RR     MEDIAN_RR          SDRR         RMSSD          SDSD  \
# count  13565.000000  13565.000000  13565.000000  13565.000000  13565.000000
# mean     786.718143    784.966582     71.124869     14.352597     14.349317
# std      155.478526    159.571871     32.606737      6.069543      6.069041
# min      411.078362    411.966595     13.786706      2.297290      2.293909
# 25%      694.610230    687.696190     51.733591      9.552529      9.551541
# 50%      795.342707    795.362000     65.212994     13.627897     13.627897
# 75%      885.026973    890.737085     86.433890     18.072109     18.069190
# max     1341.032784   1181.686350    417.129749     34.854644     34.853794
#
#          SDRR_RMSSD            HR         pNN25         pNN50           SD1  \
# count  13565.000000  13565.000000  13565.000000  13565.000000  13565.000000
# mean       5.232165     80.362350     10.326852      1.008809     10.159238
# std        1.771557     17.881308     10.732644      1.819669      4.296848
# min        1.894529     48.227524      0.000000      0.000000      1.624075
# 25%        4.023288     68.483436      2.000000      0.000000      6.762439
# 50%        5.024565     76.217835      6.500000      0.000000      9.648477
# 75%        5.979176     87.086988     15.250000      1.250000     12.792888
# max       22.172828    146.188120     46.750000     11.500000     24.676296
#
#        ...   KURT_SQUARE       HR_SQRT  MEAN_RR_MEAN_MEAN_REL_RR  \
# count  ...  1.356500e+04  13565.000000              1.356500e+04
# mean   ...  1.329781e+00      8.913462             -2.348058e+06
# std    ...  5.163260e+00      0.955308              2.711478e+08
# min    ...  5.422143e-08      6.944604             -1.399723e+10
# 25%    ...  6.183810e-02      8.275472             -3.615142e+06
# 50%    ...  2.508121e-01      8.730283             -9.468871e+05
# 75%    ...  7.103988e-01      9.332041              3.244919e+06
# max    ...  2.408444e+02     12.090828              1.385782e+10
#
#              SD2_LF         HR_LF         HR_HF        HF_VLF    subject id  \
# count  13565.000000  13565.000000  13565.000000  13565.000000  13565.000000
# mean       0.166309      0.212377      8.157914      0.042486      9.440988
# std        0.213175      0.496134     13.719796      0.084921      4.709694
# min        0.021551      0.008299      0.301723      0.000013      2.000000
# 25%        0.074520      0.048675      2.194448      0.005573      5.000000
# 50%        0.111409      0.092495      4.113742      0.014662      9.000000
# 75%        0.183800      0.204744      8.455479      0.043702     14.000000
# max        4.771071      9.698384    383.380460      1.126750     17.000000
#
#          SSSQ Label  condition label
# count  13565.000000     13565.000000
# mean       0.872392         0.771250
# std        0.777907         0.884564
# min        0.000000         0.000000
# 25%        0.000000         0.000000
# 50%        1.000000         0.000000
# 75%        1.000000         2.000000
# max        2.000000         2.000000
#
# [8 rows x 65 columns]

# %%
data.describe()
# Out:
#              MEAN_RR      MEDIAN_RR           SDRR          RMSSD  \
# count  135650.000000  135650.000000  135650.000000  135650.000000
# mean      788.515184     786.845673      71.453748      14.379418
# std       156.334847     160.113990      33.646350       6.134973
# min       411.068840     411.966595      13.786706       2.294390
# 25%       695.450860     689.389645      51.839395       9.579017
# 50%       798.200622     797.564400      65.238376      13.578235
# 75%       888.053029     892.774831      86.848219      18.170919
# max      1341.611513    1181.686350     418.066612      34.881131
#
#                 SDSD     SDRR_RMSSD             HR          pNN25  \
# count  135650.000000  135650.000000  135650.000000  135650.000000
# mean       14.376136       5.247878      80.203812      10.396622
# std         6.134411       1.792526      17.913204      10.857041
# min         2.292144       1.887603      48.183943       0.000000
# 25%         9.576334       4.025865      68.227916       2.000000
# 50%        13.576345       5.028439      75.988575       6.500000
# 75%        18.165098       6.001586      86.975168      15.500000
# max        34.880732      22.194700     146.191044      46.750000
#
#                pNN50            SD1  ...   KURT_SQUARE        HR_SQRT  \
# count  135650.000000  135650.000000  ...  1.356500e+05  135650.000000
# mean        1.026915      10.178226  ...  1.357090e+00       8.904329
# std         1.865541       4.343130  ...  5.323943e+00       0.957470
# min         0.000000       1.622825  ...  3.871992e-10       6.941465
# 25%         0.000000       6.779992  ...  6.322669e-02       8.260019
# 50%         0.000000       9.611978  ...  2.536286e-01       8.717143
# 75%         1.250000      12.860790  ...  7.131422e-01       9.326048
# max        11.500000      24.695368  ...  2.459810e+02      12.090949
#
#        MEAN_RR_MEAN_MEAN_REL_RR         SD2_LF          HR_LF          HR_HF  \
# count              1.356500e+05  135650.000000  135650.000000  135650.000000
# mean              -1.761317e+06       0.166589       0.210475       8.309048
# std                1.070482e+09       0.207166       0.469279      14.892431
# min               -3.426834e+11       0.021295       0.008200       0.294702
# 25%               -3.607337e+06       0.073939       0.048338       2.251744
# 50%               -9.391674e+05       0.111455       0.092320       4.213662
# 75%                3.286467e+06       0.184950       0.203164       8.530982
# max                1.092115e+11       4.771071       9.714187     537.538316
#
#               HF_VLF     subject id     SSSQ Label  condition label
# count  135650.000000  135650.000000  135650.000000    135650.000000
# mean        0.041303       9.398349       0.875245         0.773727
# std         0.081219       4.709621       0.780052         0.882485
# min         0.000009       2.000000       0.000000         0.000000
# 25%         0.005567       5.000000       0.000000         0.000000
# 50%         0.014356       9.000000       1.000000         0.000000
# 75%         0.042999      14.000000       1.000000         2.000000
# max         1.129262      17.000000       2.000000         2.000000
#
# [8 rows x 65 columns]

# %% [markdown]
# dividing data into X and Y variables

# %%
X=test.drop(['condition','SSSQ class','SSSQ Label','condition label','subject id'],axis='columns')
Y=["condition"]
Y=test[Y]

# %%
x=data.drop(['condition','SSSQ class','SSSQ Label','condition label','subject id'],axis='columns')
y=["condition"]
y=data[y]

# %% [markdown]
# Applyiing MinMaxScaler to normalaise the data

# %%
scaler = MinMaxScaler()
x = scaler.fit_transform(x)
X= scaler.fit_transform(X,Y)

# %% [markdown]
# converting qualitative data into qualtitaive data

# %%
la=LabelEncoder()
y=la.fit_transform(y)
Y=la.fit_transform(Y)
# Out:
# c:\Users\anura\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anura\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# Feature selection using Backward Elimination

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression

sfs = SFS(DecisionTreeClassifier(criterion = 'gini', random_state=1),
          n_jobs=-1,
          k_features=20,
          forward=False,
          floating=False,
          verbose=2,
          scoring = 'accuracy',
          cv = 0).fit(x,y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done  62 out of  62 | elapsed:  2.0min finished
#
# [2023-10-15 18:40:54] Features: 61/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:  1.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:  1.8min finished
#
# [2023-10-15 18:42:44] Features: 60/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.7min finished
#
# [2023-10-15 18:44:29] Features: 59/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done  59 out of  59 | elapsed:  1.7min finished
#
# [2023-10-15 18:46:12] Features: 58/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done  58 out of  58 | elapsed:  1.7min finished
#
# [2023-10-15 18:47:52] Features: 57/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done  55 out of  57 | elapsed:  1.6min remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done  57 out of  57 | elapsed:  1.6min finished
#
# [2023-10-15 18:49:30] Features: 56/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done  54 out of  56 | elapsed:  1.6min remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done  56 out of  56 | elapsed:  1.6min finished
#
# [2023-10-15 18:51:06] Features: 55/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done  52 out of  55 | elapsed:  1.5min remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:  1.5min finished
#
# [2023-10-15 18:52:38] Features: 54/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done  51 out of  54 | elapsed:  1.5min remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  1.5min finished
#
# [2023-10-15 18:54:08] Features: 53/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=-1)]: Done  49 out of  53 | elapsed:  1.4min remaining:    6.6s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:  1.4min finished
#
# [2023-10-15 18:55:32] Features: 52/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=-1)]: Done  48 out of  52 | elapsed:  1.2min remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:  1.4min finished
#
# [2023-10-15 18:56:59] Features: 51/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done  46 out of  51 | elapsed:  1.2min remaining:    7.5s
# [Parallel(n_jobs=-1)]: Done  51 out of  51 | elapsed:  1.4min finished
#
# [2023-10-15 18:58:20] Features: 50/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done  45 out of  50 | elapsed:  1.1min remaining:    7.4s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  1.3min finished
#
# [2023-10-15 18:59:39] Features: 49/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done  43 out of  49 | elapsed:  1.1min remaining:    9.0s
# [Parallel(n_jobs=-1)]: Done  49 out of  49 | elapsed:  1.3min finished
#
# [2023-10-15 19:00:54] Features: 48/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done  42 out of  48 | elapsed:  1.1min remaining:    8.9s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:  1.1min finished
#
# [2023-10-15 19:01:58] Features: 47/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done  40 out of  47 | elapsed:  1.0min remaining:   10.5s
# [Parallel(n_jobs=-1)]: Done  47 out of  47 | elapsed:  1.0min finished
#
# [2023-10-15 19:03:00] Features: 46/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done  39 out of  46 | elapsed:  1.0min remaining:   10.7s
# [Parallel(n_jobs=-1)]: Done  46 out of  46 | elapsed:  1.0min finished
#
# [2023-10-15 19:04:01] Features: 45/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done  37 out of  45 | elapsed:   58.9s remaining:   12.7s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:   59.7s finished
#
# [2023-10-15 19:05:01] Features: 44/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done  36 out of  44 | elapsed:   56.1s remaining:   12.4s
# [Parallel(n_jobs=-1)]: Done  44 out of  44 | elapsed:   57.1s finished
#
# [2023-10-15 19:05:59] Features: 43/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done  34 out of  43 | elapsed:   53.6s remaining:   14.1s
# [Parallel(n_jobs=-1)]: Done  43 out of  43 | elapsed:   54.9s finished
#
# [2023-10-15 19:06:54] Features: 42/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done  33 out of  42 | elapsed:   50.9s remaining:   13.8s
# [Parallel(n_jobs=-1)]: Done  42 out of  42 | elapsed:   52.3s finished
#
# [2023-10-15 19:07:47] Features: 41/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done  31 out of  41 | elapsed:   38.2s remaining:   12.2s
# [Parallel(n_jobs=-1)]: Done  41 out of  41 | elapsed:   50.2s finished
#
# [2023-10-15 19:08:37] Features: 40/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done  30 out of  40 | elapsed:   37.0s remaining:   12.3s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   47.9s finished
#
# [2023-10-15 19:09:25] Features: 39/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  39 | elapsed:   35.5s remaining:   13.9s
# [Parallel(n_jobs=-1)]: Done  39 out of  39 | elapsed:   45.9s finished
#
# [2023-10-15 19:10:12] Features: 38/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  38 | elapsed:   34.6s remaining:   14.0s
# [Parallel(n_jobs=-1)]: Done  38 out of  38 | elapsed:   44.1s finished
#
# [2023-10-15 19:10:56] Features: 37/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  37 | elapsed:   32.9s remaining:   15.7s
# [Parallel(n_jobs=-1)]: Done  37 out of  37 | elapsed:   42.8s finished
#
# [2023-10-15 19:11:39] Features: 36/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 out of  36 | elapsed:   31.8s remaining:   15.9s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:   40.8s finished
#
# [2023-10-15 19:12:20] Features: 35/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  35 | elapsed:   31.1s remaining:   18.4s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:   40.0s finished
#
# [2023-10-15 19:13:01] Features: 34/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  34 | elapsed:   29.9s remaining:   18.5s
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:   38.2s finished
#
# [2023-10-15 19:13:39] Features: 33/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  33 | elapsed:   28.6s remaining:   21.1s
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:   36.8s finished
#
# [2023-10-15 19:14:16] Features: 32/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  32 | elapsed:   27.6s remaining:   21.4s
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:   29.3s finished
#
# [2023-10-15 19:14:46] Features: 31/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  31 | elapsed:   14.8s remaining:   13.9s
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:   27.3s finished
#
# [2023-10-15 19:15:14] Features: 30/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed:   14.0s remaining:   14.0s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   25.8s finished
#
# [2023-10-15 19:15:40] Features: 29/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  29 | elapsed:   13.2s remaining:   16.3s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   24.3s finished
#
# [2023-10-15 19:16:04] Features: 28/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  28 | elapsed:   12.6s remaining:   16.8s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   23.0s finished
#
# [2023-10-15 19:16:28] Features: 27/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  27 | elapsed:   12.0s remaining:   20.5s
# [Parallel(n_jobs=-1)]: Done  24 out of  27 | elapsed:   21.4s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   21.7s finished
#
# [2023-10-15 19:16:50] Features: 26/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 out of  26 | elapsed:   11.6s remaining:   22.1s
# [Parallel(n_jobs=-1)]: Done  23 out of  26 | elapsed:   20.4s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   20.6s finished
#
# [2023-10-15 19:17:11] Features: 25/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  25 | elapsed:   10.8s remaining:   27.9s
# [Parallel(n_jobs=-1)]: Done  20 out of  25 | elapsed:   18.6s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   19.0s finished
#
# [2023-10-15 19:17:30] Features: 24/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  24 | elapsed:   10.1s remaining:   30.5s
# [Parallel(n_jobs=-1)]: Done  19 out of  24 | elapsed:   17.3s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   17.5s finished
#
# [2023-10-15 19:17:48] Features: 23/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  23 | elapsed:    9.4s remaining:   44.8s
# [Parallel(n_jobs=-1)]: Done  16 out of  23 | elapsed:   10.3s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   15.7s finished
#
# [2023-10-15 19:18:04] Features: 22/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  22 | elapsed:    9.0s remaining:   57.3s
# [Parallel(n_jobs=-1)]: Done  15 out of  22 | elapsed:    9.5s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   15.0s finished
#
# [2023-10-15 19:18:19] Features: 21/20 -- score: 1.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  21 | elapsed:    8.6s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   13.7s finished
#
# [2023-10-15 19:18:33] Features: 20/20 -- score: 1.0

# %%
x=sfs.transform(x)
X=sfs.transform(X)

# %% [markdown]
# spliting into training and testing data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=30)

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
clf=SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
ypred=clf.predict(x_test)
Y_SVM=clf.predict(X)

# %%
print('validation accuracy',accuracy_score(Y,Y_SVM))
print('validation f1 score:',f1_score(Y,Y_SVM,average='macro'))
print('validation precision score',precision_score(Y,Y_SVM,average='macro'))
print('validation recall score:',recall_score(Y,Y_SVM,average='macro'))
print('accuracy:', accuracy_score(y_test,ypred))
print('f1 score:',f1_score(y_test,ypred,average='macro'))
print('precision score',precision_score(y_test,ypred,average='macro'))
print('recall score:',recall_score(y_test,ypred,average='macro'))
# Out:
# validation accuracy 0.9096940656100257
# validation f1 score: 0.8795862132337392
# validation precision score 0.9121786776887816
# validation recall score: 0.8586862011097164
# accuracy: 0.8983280747795831
# f1 score: 0.8640752082609083
# precision score 0.9085534809075609
# recall score: 0.8392574722688145

# %%
# Assuming y_test is the actual labels and ypred is the predicted labels
cm = confusion_matrix(Y,Y_SVM)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# logistics Regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0,max_iter=1000).fit(x_train, y_train)
ypred=clf.predict(x_test)
Y_LoR=clf.predict(X)

# %%
print('validation accuracy:', accuracy_score(Y,Y_LoR))
print('validation f1 score:',f1_score(Y,Y_LoR,average='macro'))
print('validation precision score',precision_score(Y,Y_LoR,average='macro'))
print('validation recall score:',recall_score(Y,Y_LoR,average='macro'))
print('accuracy:',accuracy_score(y_test,ypred))
print('f1 score:',f1_score(y_test,ypred,average='macro'))
print('precision score',precision_score(y_test,ypred,average='macro'))
print('recall score:',recall_score(y_test,ypred,average='macro'))
# Out:
# validation accuracy: 0.7372650202727608
# validation f1 score: 0.5919401806037085
# validation precision score 0.6483724572629143
# validation recall score: 0.6034493792451149
# accuracy: 0.7387432547990446
# f1 score: 0.5837009229658043
# precision score 0.6723480105620437
# recall score: 0.5975117698181626

# %%
# Get the unique class labels from y_test and ypred
classes = np.unique(np.concatenate((Y, Y_LoR)))

# Create the confusion matrix
cm = confusion_matrix(Y, Y_LoR)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.xticks(ticks=range(len(classes)), labels=classes)
plt.yticks(ticks=range(len(classes)), labels=classes)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# accuracy of logistic regression is 75.1216 %

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=50,min_samples_split=2).fit(x_train,y_train)
ypred=clf.predict(x_test)
Y_RF=clf.predict(X)

# %%
print('validation accuracy:',accuracy_score(Y,Y_RF))
print('validation f1 score:',f1_score(Y,Y_RF,average='macro'))
print('validation precision score',precision_score(Y,Y_RF,average='macro'))
print('validation recall score:',recall_score(Y,Y_RF,average='macro'))
print('accuracy:',accuracy_score(y_test,ypred))
print('f1 score:',f1_score(y_test,ypred,average='macro'))
print('precision score',precision_score(y_test,ypred,average='macro'))
print('recall score:',recall_score(y_test,ypred,average='macro'))
# Out:
# validation accuracy: 0.9999262808698858
# validation f1 score: 0.9999025402027719
# validation precision score 0.9999537935495795
# validation recall score: 0.9998513232233126
# accuracy: 0.9999705127827087
# f1 score: 0.9999618328816161
# precision score 0.9999813613658391
# recall score: 0.9999423099111572

# %%
# Assuming y_test is the actual labels and ypred is the predicted labels
cm = confusion_matrix(Y,Y_RF)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# accuracy of Random forest is 99.9823 %

# %% [markdown]
# K-Nearest-neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
ypred = knn.predict(x_test)
Y_KNN=knn.predict(X)

# %%
print('validation accuracy:',accuracy_score(Y,Y_KNN))
print('validation f1 score:',f1_score(Y,Y_KNN,average='macro'))
print('validation precision score',precision_score(Y,Y_KNN,average='macro'))
print('validation recall score:',recall_score(Y,Y_KNN,average='macro'))
print('accuracy:',accuracy_score(y_test,ypred))
print('f1 score:',f1_score(y_test,ypred,average='macro'))
print('precision score',precision_score(y_test,ypred,average='macro'))
print('recall score:',recall_score(y_test,ypred,average='macro'))
# Out:
# validation accuracy: 0.999705123479543
# validation f1 score: 0.999677801422413
# validation precision score 0.9996429704419209
# validation recall score: 0.9997126846540626
# accuracy: 0.9999115383481261
# f1 score: 0.9998854852262983
# precision score 0.9999440903499943
# recall score: 0.9998269297334718

# %%
# Assuming y_test is the actual labels and ypred is the predicted labels
cm = confusion_matrix(Y,Y_KNN)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# accuracy of K-Nearest-neighbour is 99.9557 %

# %% [markdown]
# Naives Bayes

# %%
clf1 = GaussianNB()
clf1.fit(x_train, y_train)
ypred=clf1.predict(x_test)
Y_NB=clf1.predict(X)

# %%
print('validation accuracy:',accuracy_score(Y,Y_NB))
print('validation f1 score:',f1_score(Y,Y_NB,average='macro'))
print('validation precision score',precision_score(Y,Y_NB,average='macro'))
print('validation recall score:',recall_score(Y,Y_NB,average='macro'))
print('accuracy:',accuracy_score(y_test,ypred))
print('f1 score:',f1_score(y_test,ypred,average='macro'))
print('precision score',precision_score(y_test,ypred,average='macro'))
print('recall score:',recall_score(y_test,ypred,average='macro'))
# Out:
# validation accuracy: 0.6251382233689643
# validation f1 score: 0.5406101948911203
# validation precision score 0.5502782653565671
# validation recall score: 0.5390874950264051
# accuracy: 0.6261610591808451
# f1 score: 0.5419012363951118
# precision score 0.5542566634972331
# recall score: 0.5395078011680778

# %%
# Assuming y_test is the actual labels and ypred is the predicted labels
cm = confusion_matrix(Y,Y_NB)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Decision Tree

# %%
clf4 = DecisionTreeClassifier(criterion = 'gini', random_state=1)
clf4.fit(x_train, y_train)
ypred=clf4.predict(x_test)
Y_DF=clf4.predict(X)

# %%
print('validation accuracy:',accuracy_score(Y,Y_DF))
print('validation f1 score:',f1_score(Y,Y_DF,average='macro'))
print('validation precision score',precision_score(Y,Y_DF,average='macro'))
print('validation recall score:',recall_score(Y,Y_DF,average='macro'))
print('accuracy:',accuracy_score(y_test,ypred))
print('f1 score:',f1_score(y_test,ypred,average='macro'))
print('precision score',precision_score(y_test,ypred,average='macro'))
print('recall score:',recall_score(y_test,ypred,average='macro'))
# Out:
# validation accuracy: 0.9828234426833763
# validation f1 score: 0.9794433917009312
# validation precision score 0.9802582674249548
# validation recall score: 0.9786366969216905
# accuracy: 0.9969628166189957
# f1 score: 0.9963797747270601
# precision score 0.9968240197221125
# recall score: 0.9959395092440135

# %%
# Assuming y_test is the actual labels and ypred is the predicted labels
cm = confusion_matrix(Y,Y_DF)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Bagging

# %%
bgcl_model = BaggingClassifier(estimator=clf4, n_estimators=50,random_state=1)
bgcl_model.fit(x_train, y_train)
ypred=bgcl_model.predict(x_test)
Y_bag=bgcl_model.predict(X)

# %%
print('validation accuracy:',accuracy_score(Y,Y_bag))
print('validation f1 score:',f1_score(Y,Y_bag,average='macro'))
print('validation precision score',precision_score(Y,Y_bag,average='macro'))
print('validation recall score:',recall_score(Y,Y_bag,average='macro'))
print('accuracy:',accuracy_score(y_test,ypred))
print('f1 score:',f1_score(y_test,ypred,average='macro'))
print('precision score',precision_score(y_test,ypred,average='macro'))
print('recall score:',recall_score(y_test,ypred,average='macro'))
# Out:
# validation accuracy: 0.9939550313306303
# validation f1 score: 0.9932044459777392
# validation precision score 0.995074909146787
# validation recall score: 0.9913748829048948
# accuracy: 0.9989974346120957
# f1 score: 0.998903472330368
# precision score 0.9990434993704906
# recall score: 0.9987640480095109

# %%
# Assuming y_test is the actual labels and ypred is the predicted labels
cm = confusion_matrix(Y,Y_bag)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Boosting
# Ada Boosting

# %%
abcl_model = AdaBoostClassifier(n_estimators=10, random_state=1)
abcl_model.fit(x_train,y_train)
ypred=abcl_model.predict(x_test)
Y_ada=abcl_model.predict(X)

# %%
print('validation accuracy:',accuracy_score(Y,Y_ada))
print('validation f1 score:',f1_score(Y,Y_ada,average='macro'))
print('validation precision score',precision_score(Y,Y_ada,average='macro'))
print('validation recall score:',recall_score(Y,Y_ada,average='macro'))
print('accuracy:',accuracy_score(y_test,ypred))
print('f1 score:',f1_score(y_test,ypred,average='macro'))
print('precision score',precision_score(y_test,ypred,average='macro'))
print('recall score:',recall_score(y_test,ypred,average='macro'))
# Out:
# validation accuracy: 0.7296719498709915
# validation f1 score: 0.5286039108685766
# validation precision score 0.5005277013930187
# validation recall score: 0.567946830253432
# accuracy: 0.7276855483148056
# f1 score: 0.5297158358006474
# precision score 0.5005456886505297
# recall score: 0.570693010951148
# c:\Users\anura\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anura\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assuming y_test is the actual labels and ypred is the predicted labels
cm = confusion_matrix(Y,Y_ada)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# artificial neural network

# %%
from keras.callbacks import Callback



class Metrics(Callback):
    

    def on_train_begin(self, logs={}):
        
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []

    def on_epoch_end(self, epoch, logs={}):
        val_predict = (np.asarray(self.model.predict(self.model.validation_data[0]))).round()
        val_targ = self.model.validation_data[1]
        _val_f1 = f1_score(val_targ, val_predict)
        _val_recall = recall_score(val_targ, val_predict)
        _val_precision = precision_score(val_targ, val_predict)
        self.val_f1s.append(_val_f1)
        self.val_recalls.append(_val_recall)
        self.val_precisions.append(_val_precision)
        print(f" — val_f1: {_val_f1} — val_precision: {_val_precision} — val_recall _val_recall")
        return


metrics = Metrics()

# %%
# Create the model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(3, activation='softmax'))
model.validation_data=(x_test, y_test)

# Compile the model
# model.compile(loss='sparse_categorical_crossentropy', optimizer='Nadam', metrics=['accuracy'])

# # Train the model
# history=model.fit(x_train, y_train, batch_size=32, epochs=30, validation_split=0.2, )

# %%
# # Evaluate the model on the test set
# loss, accuracy = model.evaluate(x_test, y_test)
# print('Test loss:', loss)
# print('Test accuracy:', accuracy)

# %%
# # Get training and validation accuracy values
# training_acc = history.history['accuracy']
# validation_acc = history.history['val_accuracy']

# # validation_acc = history.history['val_accuracy']
# epochs = range(1, len(training_acc) + 1)

# # Create a plot with enhanced visual elements
# plt.figure(figsize=(8, 4))
# plt.plot(epochs, training_acc, 'b', label='Training Accuracy')
# plt.plot(epochs, validation_acc, 'r', label='Validation Accuracy')
# plt.title('Model Accuracy', fontsize=16)
# plt.xlabel('Epoch', fontsize=12)
# plt.ylabel('Accuracy', fontsize=12)
# plt.legend(fontsize=12)
# plt.grid(True)
# plt.xticks(fontsize=10)
# plt.yticks(fontsize=10)
# plt.tight_layout()

# # Display the plot
# plt.show()

# %% [markdown]
# accuracy of ANN is 92.21%

# %%
# import tensorflow as tf


# # Define the model architecture
# model = tf.keras.Sequential([
#     tf.keras.layers.Reshape((30, 1), input_shape=(30,)),
#     tf.keras.layers.Conv1D(32, 3, activation='relu'),
#     tf.keras.layers.MaxPooling1D(2),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(64, activation='relu'),
#     tf.keras.layers.Dense(10, activation='softmax')
# ])

# # Compile the model
# model.compile(optimizer='Nadam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# # Train the model
# history=model.fit(x_train, y_train, epochs=25, batch_size=16)

# %%
# # Evaluate the model on the test data
# loss, accuracy = model.evaluate(x_test, y_test)
# print(f'Test loss: {loss}, Test accuracy: {accuracy}')
